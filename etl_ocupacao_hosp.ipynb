# %% [markdown]
# **Registro de Ocupação Hospitalar COVID-19**
#
# Utilizei os Dados Abertos do Governo Federal referente a ocupação hospitalar resultante da COVID-19 no ano de 2022.
#
# Podemos fazer o download dos dados em https://dados.gov.br/dados/conjuntos-dados/registro-de-ocupacao-hospitalar-covid-19
#
# O módulo Internações foi desenvolvido para registro da ocupação de leitos clínicos e de Unidade de Terapia Intensiva (UTI) SUS destinados para atendimento aos pacientes com casos suspeitos ou confirmados da COVID-19 (ocupação SRAG / COVID-19).
#
# Alguns estados apresentam sistemas próprios de registro de ocupação e para esses foi disponibilizado uma API que transfere os dados dos estados para o sistema ESUS NOTIFICA - Módulo Internações SUS, em vigor a partir de abril de 2020.

# %%
# !pip install pandera

# %%
import pandas as pd
import pandera as pa

# %%
# carregando o arquivo e especificando a coluna com datas
df = pd.read_csv("esus-vepi.LeitoOcupacao_2022.csv", sep=",", 
                 parse_dates=["dataNotificacao"], dayfirst=True)
df.head(10)
# Out:
#    Unnamed: 0         _id                  dataNotificacao     cnes  \
# 0      641508  PBGTlqtFBP        2022-01-17 03:00:00+00:00  2379341
# 1     1275198  ipPHkH1yIB        2022-01-05 03:00:00+00:00  2594366
# 2     1290474  oDyVTndNXc 2022-01-01 03:00:50.682000+00:00  2747871
# 3     1290489  cTrwNtInVV 2022-01-01 03:00:08.570000+00:00  2082497
# 4     1290490  CPkiO32WyI 2022-01-01 03:00:14.691000+00:00  2092980
# 5     1290494  3ACxSyKSCK 2022-01-01 03:00:37.005000+00:00  2664984
# 6     1290495  NwjnjsHbot 2022-01-01 03:00:06.730000+00:00  2252260
# 7     1290496  phtJiP6gpe 2022-01-01 03:00:21.351000+00:00  2078511
# 8     1290498  DjdziRthvF 2022-01-01 03:00:37.452000+00:00  2082438
# 9     1290499  CzqSqHKQiu 2022-01-01 03:00:22.259000+00:00  2077655
#
#    ocupacaoSuspeitoCli  ocupacaoSuspeitoUti  ocupacaoConfirmadoCli  \
# 0                 13.0                  8.0                    0.0
# 1                  NaN                  NaN                    NaN
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
# 5                  NaN                  NaN                    NaN
# 6                  NaN                  NaN                    NaN
# 7                  NaN                  NaN                    NaN
# 8                  NaN                  NaN                    NaN
# 9                  NaN                  NaN                    NaN
#
#    ocupacaoConfirmadoUti  ocupacaoCovidUti  ocupacaoCovidCli  ...  \
# 0                    0.0               0.0               1.0  ...
# 1                    NaN               0.0               0.0  ...
# 2                    NaN               1.0               9.0  ...
# 3                    NaN               0.0               1.0  ...
# 4                    NaN               0.0               0.0  ...
# 5                    NaN               0.0               1.0  ...
# 6                    NaN               0.0               0.0  ...
# 7                    NaN               0.0               0.0  ...
# 8                    NaN               0.0               0.0  ...
# 9                    NaN               0.0               0.0  ...
#
#         origem        _p_usuario  estadoNotificacao  municipioNotificacao  \
# 0  parse-cloud  _User$m6WdvZgbBS     Santa Catarina                 Mafra
# 1  parse-cloud  _User$C2nTBR5lmy             Paraná              Umuarama
# 2  parse-cloud  _User$APEoiAf61c          São Paulo              Ilhabela
# 3  parse-cloud  _User$q0FgtTNz2d          São Paulo  Bernardino de Campos
# 4  parse-cloud  _User$u4yOaQOJlf          São Paulo                Bastos
# 5  parse-cloud  _User$qGap5eiTEq     Santa Catarina              Palmitos
# 6  parse-cloud  _User$xM5hias4w2  Rio Grande do Sul               Estrela
# 7  parse-cloud  _User$q46U1ECOev          São Paulo         Ilha Solteira
# 8  parse-cloud  _User$yklFg4R3ag          São Paulo             Chavantes
# 9  parse-cloud  _User$spMHnfRCha          São Paulo             São Paulo
#
#               estado             municipio excluido validado  \
# 0     Santa Catarina                 Mafra    False    False
# 1             Paraná              Umuarama    False    False
# 2          São Paulo              Ilhabela    False    False
# 3          São Paulo  Bernardino de Campos    False    False
# 4          São Paulo                Bastos    False    False
# 5     Santa Catarina              Palmitos    False    False
# 6  Rio Grande do Sul               Estrela    False    False
# 7          São Paulo         Ilha Solteira    False    False
# 8          São Paulo             Chavantes    False    False
# 9          São Paulo             São Paulo    False    False
#
#                 _created_at               _updated_at
# 0  2021-02-15T11:08:07.797Z  2022-01-17T21:56:42.351Z
# 1  2021-12-08T10:42:04.123Z  2022-01-05T14:17:35.799Z
# 2  2022-01-01T03:34:58.234Z  2022-01-01T03:34:58.234Z
# 3  2022-01-01T04:50:29.194Z  2022-01-01T04:50:29.194Z
# 4  2022-01-01T05:01:31.468Z  2022-01-01T05:01:31.468Z
# 5  2022-01-01T05:50:49.260Z  2022-01-01T05:50:49.260Z
# 6  2022-01-01T05:53:25.682Z  2022-01-01T05:53:25.682Z
# 7  2022-01-01T05:53:35.231Z  2022-01-01T05:53:35.231Z
# 8  2022-01-01T08:35:47.103Z  2022-01-01T08:35:47.103Z
# 9  2022-01-01T08:43:00.591Z  2022-01-01T08:43:00.591Z
#
# [10 rows x 26 columns]

# %%
# visualizando os tipos de dados
df.dtypes
# Out:
# Unnamed: 0                             int64
# _id                                   object
# dataNotificacao          datetime64[ns, UTC]
# cnes                                  object
# ocupacaoSuspeitoCli                  float64
# ocupacaoSuspeitoUti                  float64
# ocupacaoConfirmadoCli                float64
# ocupacaoConfirmadoUti                float64
# ocupacaoCovidUti                     float64
# ocupacaoCovidCli                     float64
# ocupacaoHospitalarUti                float64
# ocupacaoHospitalarCli                float64
# saidaSuspeitaObitos                  float64
# saidaSuspeitaAltas                   float64
# saidaConfirmadaObitos                float64
# saidaConfirmadaAltas                 float64
# origem                                object
# _p_usuario                            object
# estadoNotificacao                     object
# municipioNotificacao                  object
# estado                                object
# municipio                             object
# excluido                                bool
# validado                                bool
# _created_at                           object
# _updated_at                           object
# dtype: object

# %%
# acessando a coluna "dataNotificacao"
df.dataNotificacao
# Out:
# 0               2022-01-17 03:00:00+00:00
# 1               2022-01-05 03:00:00+00:00
# 2        2022-01-01 03:00:50.682000+00:00
# 3        2022-01-01 03:00:08.570000+00:00
# 4        2022-01-01 03:00:14.691000+00:00
#                        ...
# 291574          2022-02-23 03:00:00+00:00
# 291575          2022-02-23 03:00:00+00:00
# 291576          2022-03-22 03:00:00+00:00
# 291577          2022-02-23 03:00:00+00:00
# 291578          2022-02-24 03:00:00+00:00
# Name: dataNotificacao, Length: 291579, dtype: datetime64[ns, UTC]

# %%
# acessando o mês de cada data
df.dataNotificacao.dt.month
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 291574    2
# 291575    2
# 291576    3
# 291577    2
# 291578    2
# Name: dataNotificacao, Length: 291579, dtype: int64

# %% [markdown]
# **Validação dos Dados**
#
# Checando o conjunto de dados em relação aos tipos estipulados para a leitura do conjunto de dados.
